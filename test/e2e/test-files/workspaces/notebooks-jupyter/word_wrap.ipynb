# %% [markdown]
# # Word Wrap

# %% [markdown]
# Wide text output:
#
# - `notebook.output.wordWrap` enabled: should not wrap and not horizontally scroll
# - `notebook.output.wordWrap` disabled: should wrap and horizontally scroll

# %%
print('hello ' * 20)
